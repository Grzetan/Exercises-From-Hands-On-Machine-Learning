# %% [markdown]
# # Visualization of 2D MNIST

# %%
from sklearn.datasets import fetch_openml
import numpy as np
np.random.seed(42)

X, y = fetch_openml("mnist_784", version=1, return_X_y=True, as_frame=False)
idx = np.random.permutation(60000)[:10000]
X = X[idx]
y = y[idx]

# %%
from sklearn.manifold import TSNE

tsne = TSNE(random_state=42)
mnist2d = tsne.fit_transform(X)
mnist2d.shape
# Out:
# /home/grzetan/.local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/grzetan/.local/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# (10000, 2)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(13,10))
plt.scatter(mnist2d[:,0], mnist2d[:,1], c=y.astype(np.int8), cmap='jet')
plt.axis('off')
plt.colorbar()
plt.show()
